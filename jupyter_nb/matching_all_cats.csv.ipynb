# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
m_vlass_9 = pd.read_csv("../psrc_lists/matched_9arcsec_1and2_best1_vlass.csv")["cluster","theta_1","theta_2","ra_deg","dec_deg"]
m_first_9 = pd.read_csv("../psrc_lists/matched_9arcsec_1and2_best1_first.csv")#
m_gleam_9 = pd.read_csv("../psrc_lists/matched_9arcsec_1and2_best1_gleam.csv")
m_tgss_9 = pd.read_csv("../psrc_lists/matched_9arcsec_1and2_best1_tgss.csv")
m_lotss_9 = pd.read_csv("../psrc_lists/matched_9arcsec_1and2_best1_lotss.csv")
m_2mass_9 = pd.read_csv("../psrc_lists/matched_9arcsec_1and2_best1_2mass.csv")
m_wise_9 = pd.read_csv("../psrc_lists/matched_9arcsec_1and2_best1_wise.csv")
tabs_list = [m_vlass_9,m_first_9,m_gleam_9,m_tgss_9,m_lotss_9,m_2mass_9,m_wise_9]
labels_list = ["VLASS","FIRST","GLEAM","TGSS","LOTSS","2MASS","WISE"]

# %%
m_vlass_9.columns.values
# Out:
# array(['cluster', 'x', 'y', 'theta_1', 'theta_2', 'ra_deg', 'dec_deg',
#        'dist_center_radians', 'amp_fit', 'x_center_fit', 'y_center_fit',
#        'sigma_x_fit', 'sigma_y_fit', 'theta', 'offset', 'amp_snr',
#        'x_snr', 'y_snr', 'sigma_x_snr', 'sigma_y_snr', 'theta_snr',
#        'offset_snr', 'snr', 'masked', 'noise_ps', 'hits_ps', 'Unnamed: 0',
#        'Source', 'rms_map', 'rms_snr', 'avg_snr', 'ntail', 'amp_fit_snr',
#        'mean_fit_snr', 'std_fit_snr', 'red_type', 'Component_name',
#        'Component_id', 'Isl_id', 'RA', 'DEC', 'E_RA', 'E_DEC',
#        'Total_flux', 'E_Total_flux', 'Peak_flux', 'E_Peak_flux', 'Maj',
#        'E_Maj', 'Min', 'E_Min', 'PA', 'E_PA', 'Isl_Total_flux',
#        'E_Isl_Total_flux', 'Isl_rms', 'Isl_mean', 'Resid_Isl_rms',
#        'Resid_Isl_mean', 'RA_max', 'DEC_max', 'E_RA_max', 'E_DEC_max',
#        'S_Code', 'Xposn', 'E_Xposn', 'Yposn', 'E_Yposn', 'Xposn_max',
#        'E_Xposn_max', 'Yposn_max', 'E_Yposn_max', 'Maj_img_plane',
# ...

# %%
for i in range(len(tabs_list)-1):
    plt.hist(tabs_list[i]["Separation"],alpha=0.2,label=labels_list[i])
plt.legend()

# %%
tabs_list = [m_vlass_9,m_first_9,m_gleam_9,m_tgss_9,m_lotss_9,m_2mass_9,m_wise_9]
all_matched = tabs_list[0]
for i in range(1,len(tabs_list)):
    all_matched = all_matched.merge(tabs_list[i],how="outer",left_on=["cluster","ra_deg","dec_deg","theta_1","theta_2"],right_on=["cluster","ra_deg","dec_deg","theta_1","theta_2"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'x_center_fit_x', 'avg_snr_x', 'y_center_fit_x', 'sigma_y_snr_x', 'rms_snr_x', 'x_x', 'theta_x', 'y_x', 'mean_fit_snr_x', 'dist_center_radians_x', 'noise_ps_x', 'sigma_x_snr_x', 'hits_ps_x', 'x_snr_x', 'ntail_x', 'red_type_x', 'amp_fit_x', 'GroupID_x', 'GroupSize_x', 'amp_snr_x', 'Separation_x', 'y_snr_x', 'rms_map_x', 'offset_snr_x', 'offset_x', 'std_fit_snr_x', 'sigma_x_fit_x', 'Source_x', 'masked_x', 'sigma_y_fit_x', 'amp_fit_snr_x', 'snr_x', 'theta_snr_x', 'Unnamed: 0_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'DEC_x', 'RA_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
# ...

# %%
all_matched
# Out:
#                  cluster    x_x    y_x  theta_1  theta_2      ra_deg  \
# 0     ACT-CLJ0200.3+0019  258.0  170.0      2.0      4.0   30.037093
# 1     ACT-CLJ0200.3+0019  258.0  170.0      2.0      5.0   30.037093
# 2     ACT-CLJ0200.3+0019  258.0  170.0      2.0      6.0   30.037093
# 3     ACT-CLJ0200.3+0019  258.0  170.0      2.0      7.0   30.037093
# 4     ACT-CLJ0200.3+0019  258.0  170.0      3.0      4.0   30.037093
# ...                  ...    ...    ...      ...      ...         ...
# 1836  ACT-CLJ1343.1-0000    NaN    NaN      5.0      7.0  205.727576
# 1837  ACT-CLJ1343.1-0000    NaN    NaN      5.0      7.0  205.717576
# 1838  ACT-CLJ1343.1-0000    NaN    NaN      6.0      7.0  205.727576
# 1839  ACT-CLJ1343.1-0000    NaN    NaN      6.0      7.0  205.718687
# 1840  ACT-CLJ1343.1-0000    NaN    NaN      6.0      7.0  205.760909
#
#        dec_deg  dist_center_radians_x  amp_fit_x  x_center_fit_x  ...   w1m  \
# ...
